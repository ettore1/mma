# %% [markdown]
# # Parte 3 — Transporte, Transbordo e Designação
#
# Modelos resolvidos com **PuLP/CBC**. Funções em `src/part3.py`:
# `solve_transport(cost, supply, demand)` e `solve_assignment(cost)`.
#
# - Transporte: `min Σ c_ij x_ij` s.a. `Σ_j x_ij ≤ s_i`, `Σ_i x_ij = d_j`.
# - Designação: variáveis binárias, `Σ_j x_ij = 1`, `Σ_i x_ij = 1`.

# %%
import sys, os, importlib
sys.path.append(os.path.abspath('../src'))
import part3  # ao importar, resolve todos os exercícios e gera as figuras
print('\nResumo dos custos ótimos:')
print('Ex1 (transporte 3x4):  R$', part3.results['ex1'][1])
print('Ex2 (compra de pneus):  R$', part3.results['ex2'][1])
print('Ex3 (combustível):      ', part3.results['ex3'][1], '(mil gal x $/gal)')
print('Ex4 (Deise-Luzia):     $', part3.results['ex4'][1])
print('Ex5 (designação):       ', part3.results['ex5'][1], 'min')

# %% [markdown]
# ## Plano ótimo do Exercício 1 (matriz de transporte)

# %%
import numpy as np
X1, z1 = part3.results['ex1']
print('Custo mínimo = R$', z1)
print(np.array(X1, dtype=int))

# %%
from IPython.display import Image
Image('../figs/p3_ex5_sol.png')
